# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly as py
import plotly.graph_objs as go
import numpy as np
import plotly.figure_factory as ff
#plotly.tools.set_credentials_file(username='yaghdev', api_key='BZvETrFTjtGisnoBsxAP')

# %%
year_1 = ['2004', '2005', '2006', '2007', '2008']
year_2 = ['2009', '2010', '2011', '2012', '2013']
year_3 = ['2014', '2015', '2016', '2017', '2018']

page_rank_us = []
degree_us = []
betweeness_us = []
eigenvalue_us = []
closeness_us = []
for i in year_1:    
    excel_1 = pd.read_excel('D:/new_ft50/Insitutional_result/year_wise/Insitutional_network_'+str(i)+'.xlsx')  
    excel_1 = excel_1.loc[excel_1['Insitute'].apply(lambda x: x[-4:] == 'USA.')]
    degree_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[4])
    betweeness_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[2])
    closeness_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[1])
    eigenvalue_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[0])

# %%
data1 = degree_us
data2 = betweeness_us
data3 = closeness_us
data4 = eigenvalue_us

year = year_1
fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.plot(year, data1, 'ro', color ='b')  
ax1.plot(year, data2, 'ro', color ='r')  
ax1.plot(year, data3, 'ro', color ='y')     
ax1.plot(year, data4, 'ro', color ='m')
ax1.legend(['pagerank - degree', 'pagerank - betweeness', 'pagerank - closeness', 'pagerank - eigenvalue'], loc='upper right')
plt.show()

# %%
degree_nonus = []
betweeness_nonus = []
eigenvalue_nonus = []
closeness_nonus = []

for i in year_1:    
    excel_1 = pd.read_excel('D:/new_ft50/Insitutional_result/year_wise/Insitutional_network_'+str(i)+'.xlsx')
    excel_1 = excel_1.loc[excel_1['Insitute'].apply(lambda x: x[-4:] != 'USA.')]
    degree_nonus.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[4])
    betweeness_nonus.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[2])
    closeness_nonus.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[1])
    eigenvalue_nonus.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[0])

# %%
data1 = degree_nonus
data2 = betweeness_nonus
data3 = closeness_nonus
data4 = eigenvalue_nonus

year = year_1
fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.plot(year, data1, 'ro', color ='b')  
ax1.plot(year, data2, 'ro', color ='r')  
ax1.plot(year, data3, 'ro', color ='y')     
ax1.plot(year, data4, 'ro', color ='m')
ax1.legend(['pagerank - degree', 'pagerank - betweeness', 'pagerank - closeness', 'pagerank - eigenvalue'], loc='upper right')
plt.show()

# %%
degree = []
betweeness = []
eigenvalue = []
closeness = []

for i in year_1:    
    excel_1 =  pd.read_excel('D:/new_ft50/Insitutional_result/year_wise/Insitutional_network_'+str(i)+'.xlsx') 
    degree.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[4])
    betweeness.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[2])
    closeness.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[1])
    eigenvalue.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[0])

# %%
data1 = degree
data2 = betweeness
data3 = closeness
data4 = eigenvalue
year = year_1 

fig, ax1 = plt.subplots(figsize=(10, 8))
ax1.plot(year, data1, 'ro', color ='b')  
ax1.plot(year, data2, 'ro', color ='r')  
ax1.plot(year, data3, 'ro', color ='y')     
ax1.plot(year, data4, 'ro', color ='m')
ax1.legend(['pagerank - degree', 'pagerank - betweeness', 'pagerank - closeness', 'pagerank - eigenvalue'], loc='upper right')
plt.show()

# %%
list_1 = ['Accounting', 'Economics', 'Entrepreneurship', 'Ethics', 'Finance', 'Human Resources', 'International Business', 'Management', 'Marketing', 'Operations & Information Systems', 'Organizational Behaviour']
count = 1
fig, axs = plt.subplots(4, 3,figsize=(15,15))

for i in list_1:    
    excel_1 = pd.read_excel('D:/new_ft50/Insitutional_result/subject_wise/Insitutional_'+str(i)+'.xlsx')  
    excel_1 = excel_1.loc[excel_1['Insitute'].apply(lambda x: x[-4:] == 'USA.')]
    degree_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[4])
    betweeness_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[2])
    closeness_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[1])
    eigenvalue_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[0])  
    
    axs[count % 4, count % 3].plot(year, data1, 'ro', color ='b')  
    axs[count % 4, count % 3].plot(year, data2, 'ro', color ='r')  
    axs[count % 4, count % 3].plot(year, data3, 'ro', color ='y')     
    axs[count % 4, count % 3].plot(year, data4, 'ro', color ='m')
    
    axs[count % 4, count % 3].set_title(i)    
    count+=1

# %%
list_1 = ['Accounting', 'Economics', 'Entrepreneurship', 'Ethics', 'Finance', 'Human Resources', 'International Business', 'Management', 'Marketing', 'Operations & Information Systems', 'Organizational Behaviour']
count = 1
fig, axs = plt.subplots(4, 3,figsize=(15,15))

for i in list_1:
    excel_1 = pd.read_excel('D:/new_ft50/Insitutional_result/subject_wise/Insitutional_'+str(i)+'.xlsx')  
    excel_1 = excel_1.loc[excel_1['Insitute'].apply(lambda x: x[-4:] == 'USA.')]
    degree_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[4])
    betweeness_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[2])
    closeness_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[1])
    eigenvalue_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[0])  
    
    axs[count % 4, count % 3].plot(list_1, degree_us, 'ro', color ='b')  
    axs[count % 4, count % 3].plot(list_1, betweeness_us, 'ro', color ='r')  
    axs[count % 4, count % 3].plot(list_1, closeness_us, 'ro', color ='y')     
    axs[count % 4, count % 3].plot(list_1, eigenvalue_us, 'ro', color ='m')
    
    axs[count % 4, count % 3].set_title(i)    
    count+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-598cbf9f73ea> in <module>
#      11     eigenvalue_us.append(excel_1.corr(method='pearson', min_periods=1).loc['page rank'].values[0])
#      12
# ---> 13     axs[count % 4, count % 3].plot(list_1, degree_us, 'ro', color ='b')
#      14     axs[count % 4, count % 3].plot(list_1, betweeness_us, 'ro', color ='r')
#      15     axs[count % 4, count % 3].plot(list_1, closeness_us, 'ro', color ='y')
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...
