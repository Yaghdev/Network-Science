# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
plotly.tools.set_credentials_file(username='yaghdev', api_key='BZvETrFTjtGisnoBsxAP')

# %%
excel = pd.read_csv('C:/Users/Krishan/Downloads/FT50_WOS/insitutional_year_wise_all/edges/edges_2005.csv')
insitute_with_in_usa = excel.loc[(excel['Source'].apply(lambda x: x[-4:] == 'USA.')) & (excel['Target'].apply(lambda x: x[-4:] != 'USA.')) | (excel['Source'].apply(lambda x: x[-4:] != 'USA.')) & (excel['Target'].apply(lambda x: x[-4:] == 'USA.'))]
# insitute_with_in_usa['Source'] = insitute_with_in_usa['Source'].apply(lambda x: x.split(",")[0] + x.split(",")[-1])
# insitute_with_in_usa['Source'] = insitute_with_in_usa['Source'].apply(lambda x: "NBER MA 02138 USA." if x == "Natl Bur Econ Res MA 02138 USA." else x)
insitute_with_in_usa = insitute_with_in_usa.sort_values(by='Weight', ascending=False)

# %%
result = insitute_with_in_usa.groupby(['Source']).agg({'Source':'count', 'Weight':'sum'}).sort_values(by='Weight', ascending=False)
result['rank'] = [x for x in range(1, len(result)+1)]
result['percentile'] = (len(result)-result['rank'])/len(result)*100
result['quantiles'] = pd.qcut(result['rank'], 4, labels=False)
result.loc[result['quantiles'] == 0] 
 # count in target also because it is undirected
# Out:
#                                                     Source  Weight  rank  \
# Source
# Natl Bur Econ Res, Cambridge, MA 02138 USA.             14      15     1
# London Business Sch, London NW1 4SA, England.           12      15     2
# INSEAD, F-77305 Fontainebleau, France.                  10      11     3
# Univ Penn, Wharton Sch, Philadelphia, PA 19104 ...      10      10     4
# Stanford Univ, Grad Sch Business, Stanford, CA ...       8       8     5
# Columbia Univ, Grad Sch Business, New York, NY ...       7       7     6
# NBER, Cambridge, MA 02138 USA.                           7       7     7
# Univ Penn, Philadelphia, PA 19104 USA.                   7       7     8
# Hong Kong Univ Sci & Technol, Hong Kong, Hong K...       6       6     9
# Arizona State Univ, WP Carey Sch Business, Temp...       5       6    10
# Emory Univ, Goizueta Business Sch, Atlanta, GA ...       6       6    11
# Univ Maryland, Robert H Smith Sch Business, Col...       6       6    12
# Univ Melbourne, Parkville, Vic 3052, Australia.          5       6    13
# Univ Auckland, Auckland 1, New Zealand.                  6       6    14
# Harvard Univ, Dept Econ, Cambridge, MA 02138 USA.        6       6    15
# Univ Western Ontario, Richard Ivey Sch Business...       5       5    16
# Harvard Univ, Cambridge, MA 02138 USA.                   5       5    17
# Ohio State Univ, Fisher Coll Business, Columbus...       5       5    18
# Univ Minnesota, Carlson Sch Management, Minneap...       5       5    19
# NYU, Stern Sch Business, New York, NY 10012 USA.         5       5    20
# Harvard Univ, Sch Business, Cambridge, MA 02138...       5       5    21
# Arizona State Univ, WP Carey Sch Business, Dept...       3       5    22
# Univ S Carolina, Moore Sch Business, Columbia, ...       5       5    23
# Univ Calif Los Angeles, Los Angeles, CA 90024 USA.       5       5    24
# NYU, New York, NY 10012 USA.                             4       4    25
# Duke Univ, Fuqua Sch Business, Durham, NC 27706...       4       4    26
# Northwestern Univ, Kellogg Sch Management, Evan...       4       4    27
# MIT, Cambridge, MA 02139 USA.                            4       4    28
# Singapore Management Univ, Singapore, Singapore.         4       4    29
# Technion Israel Inst Technol, Fac Ind Engn & Ma...       4       4    30
# ...                                                    ...     ...   ...
# Univ Alberta, Sch Business, Edmonton, AB T6G 2R...       3       3    84
# York Univ, Schulich Sch Business, N York, ON M3...       3       3    85
# Duke Univ, Fuqua Sch Business, Durham, NC 27708...       3       3    86
# Boston Univ, Sch Management, Boston, MA 02215 USA.       3       3    87
# Chinese Univ Hong Kong, Hong Kong, Hong Kong, P...       3       3    88
# Univ Missouri, Coll Business Adm, St Louis, MO ...       1       2    89
# Univ Modena, Dipartimento Ingn Meccan & Civile,...       2       2    90
# Rutgers State Univ, Sch Management & Labor Rela...       2       2    91
# Rutgers State Univ, Piscataway, NJ 08855 USA.            2       2    92
# Rice Univ, Jesse H Jones Grad Sch Management, H...       2       2    93
# Rice Univ, Dept Psychol, Houston, TX 77005 USA.          2       2    94
# Rensselaer Polytech Inst, Lally Sch Management ...       2       2    95
# Univ New Hampshire, Wittemore Sch Business & Ec...       2       2    96
# Cornell Univ, Johnson Grad Sch Management, Itha...       2       2    97
# Purdue Univ, Mil Family Res Inst, W Lafayette, ...       2       2    98
# Purdue Univ, Krannert Sch Management, W Lafayet...       2       2    99
# Purdue Univ, Dept Psychol Sci, W Lafayette, IN ...       2       2   100
# Boston Consulting Grp Inc, Chicago, IL USA.              2       2   101
# Sogang Univ, Dept Comp Sci & Engn, Seoul 121742...       2       2   102
# Penn State Univ, University Pk, PA 16802 USA.            2       2   103
# Boston Coll, Org Studies Dept, Chestnut Hill, M...       2       2   104
# Boston Coll, Chestnut Hill, MA 02167 USA.                2       2   105
# Northwestern Univ, Kellogg Sch Management, Dept...       2       2   106
# Northwestern Univ, JL Kellogg Grad Sch Manageme...       2       2   107
# Delft Univ Technol, Fac Technol Policy & Manage...       2       2   108
# Univ Queensland, St Lucia, Qld 4067, Australia.          2       2   109
# Univ Sassari, Ente Luigi Einaudi, I-07100 Sassa...       2       2   110
# Univ So Calif, Marshall Sch Business, Los Angel...       2       2   111
# NYU, New York, NY USA.                                   2       2   112
# Univ So Maine, Sch Business, Portland, ME 04104...       2       2   113
#
#                                                     percentile  quantiles
# Source
# Natl Bur Econ Res, Cambridge, MA 02138 USA.          99.777283          0
# London Business Sch, London NW1 4SA, England.        99.554566          0
# INSEAD, F-77305 Fontainebleau, France.               99.331849          0
# Univ Penn, Wharton Sch, Philadelphia, PA 19104 ...   99.109131          0
# Stanford Univ, Grad Sch Business, Stanford, CA ...   98.886414          0
# Columbia Univ, Grad Sch Business, New York, NY ...   98.663697          0
# NBER, Cambridge, MA 02138 USA.                       98.440980          0
# Univ Penn, Philadelphia, PA 19104 USA.               98.218263          0
# Hong Kong Univ Sci & Technol, Hong Kong, Hong K...   97.995546          0
# Arizona State Univ, WP Carey Sch Business, Temp...   97.772829          0
# Emory Univ, Goizueta Business Sch, Atlanta, GA ...   97.550111          0
# Univ Maryland, Robert H Smith Sch Business, Col...   97.327394          0
# Univ Melbourne, Parkville, Vic 3052, Australia.      97.104677          0
# Univ Auckland, Auckland 1, New Zealand.              96.881960          0
# Harvard Univ, Dept Econ, Cambridge, MA 02138 USA.    96.659243          0
# Univ Western Ontario, Richard Ivey Sch Business...   96.436526          0
# Harvard Univ, Cambridge, MA 02138 USA.               96.213808          0
# Ohio State Univ, Fisher Coll Business, Columbus...   95.991091          0
# Univ Minnesota, Carlson Sch Management, Minneap...   95.768374          0
# NYU, Stern Sch Business, New York, NY 10012 USA.     95.545657          0
# Harvard Univ, Sch Business, Cambridge, MA 02138...   95.322940          0
# Arizona State Univ, WP Carey Sch Business, Dept...   95.100223          0
# Univ S Carolina, Moore Sch Business, Columbia, ...   94.877506          0
# Univ Calif Los Angeles, Los Angeles, CA 90024 USA.   94.654788          0
# NYU, New York, NY 10012 USA.                         94.432071          0
# Duke Univ, Fuqua Sch Business, Durham, NC 27706...   94.209354          0
# Northwestern Univ, Kellogg Sch Management, Evan...   93.986637          0
# MIT, Cambridge, MA 02139 USA.                        93.763920          0
# Singapore Management Univ, Singapore, Singapore.     93.541203          0
# Technion Israel Inst Technol, Fac Ind Engn & Ma...   93.318486          0
# ...                                                        ...        ...
# Univ Alberta, Sch Business, Edmonton, AB T6G 2R...   81.291759          0
# York Univ, Schulich Sch Business, N York, ON M3...   81.069042          0
# Duke Univ, Fuqua Sch Business, Durham, NC 27708...   80.846325          0
# Boston Univ, Sch Management, Boston, MA 02215 USA.   80.623608          0
# Chinese Univ Hong Kong, Hong Kong, Hong Kong, P...   80.400891          0
# Univ Missouri, Coll Business Adm, St Louis, MO ...   80.178174          0
# Univ Modena, Dipartimento Ingn Meccan & Civile,...   79.955457          0
# Rutgers State Univ, Sch Management & Labor Rela...   79.732739          0
# Rutgers State Univ, Piscataway, NJ 08855 USA.        79.510022          0
# Rice Univ, Jesse H Jones Grad Sch Management, H...   79.287305          0
# Rice Univ, Dept Psychol, Houston, TX 77005 USA.      79.064588          0
# Rensselaer Polytech Inst, Lally Sch Management ...   78.841871          0
# Univ New Hampshire, Wittemore Sch Business & Ec...   78.619154          0
# Cornell Univ, Johnson Grad Sch Management, Itha...   78.396437          0
# Purdue Univ, Mil Family Res Inst, W Lafayette, ...   78.173719          0
# Purdue Univ, Krannert Sch Management, W Lafayet...   77.951002          0
# Purdue Univ, Dept Psychol Sci, W Lafayette, IN ...   77.728285          0
# Boston Consulting Grp Inc, Chicago, IL USA.          77.505568          0
# Sogang Univ, Dept Comp Sci & Engn, Seoul 121742...   77.282851          0
# Penn State Univ, University Pk, PA 16802 USA.        77.060134          0
# Boston Coll, Org Studies Dept, Chestnut Hill, M...   76.837416          0
# Boston Coll, Chestnut Hill, MA 02167 USA.            76.614699          0
# Northwestern Univ, Kellogg Sch Management, Dept...   76.391982          0
# Northwestern Univ, JL Kellogg Grad Sch Manageme...   76.169265          0
# Delft Univ Technol, Fac Technol Policy & Manage...   75.946548          0
# Univ Queensland, St Lucia, Qld 4067, Australia.      75.723831          0
# Univ Sassari, Ente Luigi Einaudi, I-07100 Sassa...   75.501114          0
# Univ So Calif, Marshall Sch Business, Los Angel...   75.278396          0
# NYU, New York, NY USA.                               75.055679          0
# Univ So Maine, Sch Business, Portland, ME 04104...   74.832962          0
#
# [113 rows x 5 columns]

# %%
excel = pd.read_csv('C:/Users/Krishan/Downloads/FT50_WOS/insitutional_year_wise_all/edges/edges_2005.csv')
insitute_with_in_usa = excel.loc[(excel['Source'].apply(lambda x: x[-4:] == 'USA.')) & (excel['Target'].apply(lambda x: x[-4:] == 'USA.'))]
insitute_with_in_usa['Source'] = insitute_with_in_usa['Source'].apply(lambda x: x.split(",")[0] + x.split(",")[-1])
insitute_with_in_usa['Source'] = insitute_with_in_usa['Source'].apply(lambda x: "NBER MA 02138 USA." if x == "Natl Bur Econ Res MA 02138 USA." else x)
insitute_with_in_usa = insitute_with_in_usa.sort_values(by='Weight', ascending=False)
# Out:
# C:\Users\Krishan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Krishan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result = insitute_with_in_usa.groupby(['Source']).agg({'Source':'count', 'Weight':'sum'}).sort_values(by='Weight', ascending=False)
result['rank'] = [x for x in range(1, len(result)+1)]
result['percentile'] = (len(result)-result['rank'])/len(result)*100
result['quantiles'] = pd.qcut(result['rank'], 4, labels=False)
result.loc[result['quantiles'] == 0]
# Out:
#                                         Source  Weight  rank  percentile  \
# Source
# NBER MA 02138 USA.                         115     163     1   99.722222
# Univ Penn PA 19104 USA.                     65      76     2   99.444444
# Harvard Univ MA 02138 USA.                  46      68     3   99.166667
# Univ Chicago IL 60637 USA.                  41      57     4   98.888889
# Stanford Univ CA 94305 USA.                 46      55     5   98.611111
# Arizona State Univ AZ 85287 USA.            39      41     6   98.333333
# Univ Maryland MD 20742 USA.                 37      38     7   98.055556
# Columbia Univ NY 10027 USA.                 30      37     8   97.777778
# Northwestern Univ IL 60208 USA.             37      37     9   97.500000
# Carnegie Mellon Univ PA 15213 USA.          35      35    10   97.222222
# Univ Minnesota MN 55455 USA.                29      34    11   96.944444
# Univ Texas TX 78712 USA.                    28      30    12   96.666667
# Emory Univ GA 30322 USA.                    26      29    13   96.388889
# Univ Michigan MI 48109 USA.                 28      29    14   96.111111
# Duke Univ NC 27708 USA.                     26      29    15   95.833333
# Texas A&M Univ TX 77843 USA.                29      29    16   95.555556
# Penn State Univ PA 16802 USA.               27      29    17   95.277778
# Univ Notre Dame IN 46556 USA.               27      28    18   95.000000
# Cornell Univ NY 14853 USA.                  26      27    19   94.722222
# Ohio State Univ OH 43210 USA.               23      26    20   94.444444
# Univ Arizona AZ 85721 USA.                  23      26    21   94.166667
# Univ Calif Berkeley CA 94720 USA.           25      26    22   93.888889
# Univ So Calif CA 90089 USA.                 26      26    23   93.611111
# Indiana Univ IN 47405 USA.                  24      24    24   93.333333
# MIT MA 02142 USA.                           23      24    25   93.055556
# Princeton Univ NJ 08544 USA.                16      23    26   92.777778
# Duke Univ NC 27706 USA.                     21      23    27   92.500000
# Michigan State Univ MI 48824 USA.           20      20    28   92.222222
# Georgia Inst Technol GA 30332 USA.          18      19    29   91.944444
# NYU NY 10012 USA.                           17      17    30   91.666667
# ...                                        ...     ...   ...         ...
# Rensselaer Polytech Inst NY 12180 USA.       7       8    61   83.055556
# Louisiana State Univ LA 70803 USA.           8       8    62   82.777778
# Univ Utah UT 84112 USA.                      8       8    63   82.500000
# Univ Houston TX 77204 USA.                   8       8    64   82.222222
# Dartmouth Coll NH 03755 USA.                 6       8    65   81.944444
# Univ Wisconsin WI 53201 USA.                 8       8    66   81.666667
# Univ Cent Florida FL 32816 USA.              7       7    67   81.388889
# Int Monetary Fund DC 20431 USA.              6       7    68   81.111111
# Univ Calif Los Angeles CA 90024 USA.         7       7    69   80.833333
# Claremont Grad Univ CA 91771 USA.            7       7    70   80.555556
# Univ Iowa IA 52242 USA.                      7       7    71   80.277778
# SUNY Buffalo NY 14260 USA.                   7       7    72   80.000000
# Univ Kentucky KY 40506 USA.                  7       7    73   79.722222
# George Washington Univ DC 20052 USA.         7       7    74   79.444444
# NYU NY 10003 USA.                            6       6    75   79.166667
# Texas Christian Univ TX 76129 USA.           6       6    76   78.888889
# Washington Univ MO 63130 USA.                6       6    77   78.611111
# RAND Corp CA 90407 USA.                      6       6    78   78.333333
# Univ N Carolina NC 28223 USA.                6       6    79   78.055556
# Georgetown Univ DC 20057 USA.                6       6    80   77.777778
# Univ New Orleans LA 70148 USA.               6       6    81   77.500000
# Univ Missouri MO 65211 USA.                  5       5    82   77.222222
# Boston Coll MA 02167 USA.                    5       5    83   76.944444
# Drexel Univ PA 19104 USA.                    5       5    84   76.666667
# Depaul Univ IL 60604 USA.                    5       5    85   76.388889
# Dartmouth Coll NH USA.                       5       5    86   76.111111
# Univ Illinois IL 61801 USA.                  4       4    87   75.833333
# Univ Tennessee TN 37996 USA.                 4       4    88   75.555556
# Baylor Univ TX 76798 USA.                    3       4    89   75.277778
# Univ Arkansas AR 72701 USA.                  4       4    90   75.000000
#
#                                         quantiles
# Source
# NBER MA 02138 USA.                              0
# Univ Penn PA 19104 USA.                         0
# Harvard Univ MA 02138 USA.                      0
# Univ Chicago IL 60637 USA.                      0
# Stanford Univ CA 94305 USA.                     0
# Arizona State Univ AZ 85287 USA.                0
# Univ Maryland MD 20742 USA.                     0
# Columbia Univ NY 10027 USA.                     0
# Northwestern Univ IL 60208 USA.                 0
# Carnegie Mellon Univ PA 15213 USA.              0
# Univ Minnesota MN 55455 USA.                    0
# Univ Texas TX 78712 USA.                        0
# Emory Univ GA 30322 USA.                        0
# Univ Michigan MI 48109 USA.                     0
# Duke Univ NC 27708 USA.                         0
# Texas A&M Univ TX 77843 USA.                    0
# Penn State Univ PA 16802 USA.                   0
# Univ Notre Dame IN 46556 USA.                   0
# Cornell Univ NY 14853 USA.                      0
# Ohio State Univ OH 43210 USA.                   0
# Univ Arizona AZ 85721 USA.                      0
# Univ Calif Berkeley CA 94720 USA.               0
# Univ So Calif CA 90089 USA.                     0
# Indiana Univ IN 47405 USA.                      0
# MIT MA 02142 USA.                               0
# Princeton Univ NJ 08544 USA.                    0
# Duke Univ NC 27706 USA.                         0
# Michigan State Univ MI 48824 USA.               0
# Georgia Inst Technol GA 30332 USA.              0
# NYU NY 10012 USA.                               0
# ...                                           ...
# Rensselaer Polytech Inst NY 12180 USA.          0
# Louisiana State Univ LA 70803 USA.              0
# Univ Utah UT 84112 USA.                         0
# Univ Houston TX 77204 USA.                      0
# Dartmouth Coll NH 03755 USA.                    0
# Univ Wisconsin WI 53201 USA.                    0
# Univ Cent Florida FL 32816 USA.                 0
# Int Monetary Fund DC 20431 USA.                 0
# Univ Calif Los Angeles CA 90024 USA.            0
# Claremont Grad Univ CA 91771 USA.               0
# Univ Iowa IA 52242 USA.                         0
# SUNY Buffalo NY 14260 USA.                      0
# Univ Kentucky KY 40506 USA.                     0
# George Washington Univ DC 20052 USA.            0
# NYU NY 10003 USA.                               0
# Texas Christian Univ TX 76129 USA.              0
# Washington Univ MO 63130 USA.                   0
# RAND Corp CA 90407 USA.                         0
# Univ N Carolina NC 28223 USA.                   0
# Georgetown Univ DC 20057 USA.                   0
# Univ New Orleans LA 70148 USA.                  0
# Univ Missouri MO 65211 USA.                     0
# Boston Coll MA 02167 USA.                       0
# Drexel Univ PA 19104 USA.                       0
# Depaul Univ IL 60604 USA.                       0
# Dartmouth Coll NH USA.                          0
# Univ Illinois IL 61801 USA.                     0
# Univ Tennessee TN 37996 USA.                    0
# Baylor Univ TX 76798 USA.                       0
# Univ Arkansas AR 72701 USA.                     0
#
# [90 rows x 5 columns]

# %%
excel = pd.read_csv('C:/Users/Krishan/Downloads/FT50_WOS/insitutional_year_wise_all/edges/edges_2005.csv')
insitute_with_in_usa = excel.loc[(excel['Source'].apply(lambda x: x[-4:] != 'USA.')) & (excel['Target'].apply(lambda x: x[-4:] != 'USA.'))]
insitute_with_in_usa['Source'] = insitute_with_in_usa['Source'].apply(lambda x: x.split(",")[0] + x.split(",")[-1])
insitute_with_in_usa['Source'] = insitute_with_in_usa['Source'].apply(lambda x: "NBER MA 02138 USA." if x == "Natl Bur Econ Res MA 02138 USA." else x)
insitute_with_in_usa = insitute_with_in_usa.sort_values(by='Weight', ascending=False)
# Out:
# C:\Users\Krishan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Krishan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result = insitute_with_in_usa.groupby(['Source']).agg({'Source':'count', 'Weight':'sum'}).sort_values(by='Weight', ascending=False)
result['rank'] = [x for x in range(1, len(result)+1)]
result['percentile'] = (len(result)-result['rank'])/len(result)*100
result['quantiles'] = pd.qcut(result['rank'], 4, labels=False)
result.loc[result['quantiles'] == 0]
# Out:
#                                                     Source  Weight  rank  \
# Source
# London Business Sch England.                            24      24     1
# Univ Nottingham England.                                19      19     2
# Erasmus Univ Netherlands.                               17      17     3
# Univ British Columbia Canada.                           16      16     4
# Univ Queensland Australia.                              15      15     5
# Tilburg Univ Netherlands.                               13      13     6
# Maastricht Univ Netherlands.                            12      12     7
# Hong Kong Univ Sci & Technol Peoples R China.           12      12     8
# Natl Univ Singapore Singapore.                          11      11     9
# Univ Toronto Canada.                                    11      11    10
# Catholic Univ Louvain Belgium.                          11      11    11
# CEPR England.                                            9      10    12
# Univ London London Sch Econ & Polit Sci England.        10      10    13
# UCL England.                                             9       9    14
# HEC Montreal Canada.                                     7       9    15
# Univ Bologna Italy.                                      9       9    16
# Concordia Univ Canada.                                   9       9    17
# Univ Melbourne Australia.                                8       8    18
# Univ Montreal Canada.                                    8       8    19
# Univ Manchester England.                                 8       8    20
# INSEAD France.                                           8       8    21
# Univ Oxford England.                                     8       8    22
# Univ Cambridge England.                                  8       8    23
# Simon Fraser Univ Canada.                                6       7    24
# De Montfort Univ England.                                7       7    25
# London Sch Econ England.                                 6       6    26
# Lund Univ Sweden.                                        6       6    27
# Technion Israel Inst Technol Israel.                     6       6    28
# Univ Leicester England.                                  6       6    29
# Univ Alberta Canada.                                     6       6    30
# ...                                                    ...     ...   ...
# Free Univ Amsterdam Netherlands.                         5       5    42
# Chinese Univ Hong Kong Peoples R China.                  5       5    43
# Univ Auckland New Zealand.                               5       5    44
# Univ Antwerp Belgium.                                    5       5    45
# Catholic Univ Italy.                                     5       5    46
# Hebrew Univ Jerusalem Israel.                            4       4    47
# Peking Univ Peoples R China.                             4       4    48
# Queens Univ Canada.                                      4       4    49
# Max Planck Inst Econ Germany.                            4       4    50
# Univ Sheffield England.                                  4       4    51
# McMaster Univ Canada.                                    4       4    52
# Katholieke Univ Leuven Belgium.                          4       4    53
# Univ Pompeu Fabra Spain.                                 4       4    54
# Kings Coll London England.                               4       4    55
# City Univ London England.                                4       4    56
# Natl Chengchi Univ Taiwan.                               4       4    57
# Eindhoven Univ Technol Netherlands.                      4       4    58
# Univ Warwick England.                                    4       4    59
# Max Planck Inst Germany.                                 3       3    60
# LaRIA France.                                            3       3    61
# Univ London Royal Holloway & Bedford New Coll E...       3       3    62
# IZA Germany.                                             3       3    63
# Tech Univ Eindhoven Netherlands.                         3       3    64
# Quintiq Netherlands.                                     3       3    65
# Univ London England.                                     3       3    66
# Bank England England.                                    3       3    67
# Tech Univ Freiberg Germany.                              3       3    68
# Indiana Univ Germany.                                    3       3    69
# Tel Aviv Univ Israel.                                    3       3    70
# Univ Southampton England.                                3       3    71
#
#                                                     percentile  quantiles
# Source
# London Business Sch England.                         99.644128          0
# Univ Nottingham England.                             99.288256          0
# Erasmus Univ Netherlands.                            98.932384          0
# Univ British Columbia Canada.                        98.576512          0
# Univ Queensland Australia.                           98.220641          0
# Tilburg Univ Netherlands.                            97.864769          0
# Maastricht Univ Netherlands.                         97.508897          0
# Hong Kong Univ Sci & Technol Peoples R China.        97.153025          0
# Natl Univ Singapore Singapore.                       96.797153          0
# Univ Toronto Canada.                                 96.441281          0
# Catholic Univ Louvain Belgium.                       96.085409          0
# CEPR England.                                        95.729537          0
# Univ London London Sch Econ & Polit Sci England.     95.373665          0
# UCL England.                                         95.017794          0
# HEC Montreal Canada.                                 94.661922          0
# Univ Bologna Italy.                                  94.306050          0
# Concordia Univ Canada.                               93.950178          0
# Univ Melbourne Australia.                            93.594306          0
# Univ Montreal Canada.                                93.238434          0
# Univ Manchester England.                             92.882562          0
# INSEAD France.                                       92.526690          0
# Univ Oxford England.                                 92.170819          0
# Univ Cambridge England.                              91.814947          0
# Simon Fraser Univ Canada.                            91.459075          0
# De Montfort Univ England.                            91.103203          0
# London Sch Econ England.                             90.747331          0
# Lund Univ Sweden.                                    90.391459          0
# Technion Israel Inst Technol Israel.                 90.035587          0
# Univ Leicester England.                              89.679715          0
# Univ Alberta Canada.                                 89.323843          0
# ...                                                        ...        ...
# Free Univ Amsterdam Netherlands.                     85.053381          0
# Chinese Univ Hong Kong Peoples R China.              84.697509          0
# Univ Auckland New Zealand.                           84.341637          0
# Univ Antwerp Belgium.                                83.985765          0
# Catholic Univ Italy.                                 83.629893          0
# Hebrew Univ Jerusalem Israel.                        83.274021          0
# Peking Univ Peoples R China.                         82.918149          0
# Queens Univ Canada.                                  82.562278          0
# Max Planck Inst Econ Germany.                        82.206406          0
# Univ Sheffield England.                              81.850534          0
# McMaster Univ Canada.                                81.494662          0
# Katholieke Univ Leuven Belgium.                      81.138790          0
# Univ Pompeu Fabra Spain.                             80.782918          0
# Kings Coll London England.                           80.427046          0
# City Univ London England.                            80.071174          0
# Natl Chengchi Univ Taiwan.                           79.715302          0
# Eindhoven Univ Technol Netherlands.                  79.359431          0
# Univ Warwick England.                                79.003559          0
# Max Planck Inst Germany.                             78.647687          0
# LaRIA France.                                        78.291815          0
# Univ London Royal Holloway & Bedford New Coll E...   77.935943          0
# IZA Germany.                                         77.580071          0
# Tech Univ Eindhoven Netherlands.                     77.224199          0
# Quintiq Netherlands.                                 76.868327          0
# Univ London England.                                 76.512456          0
# Bank England England.                                76.156584          0
# Tech Univ Freiberg Germany.                          75.800712          0
# Indiana Univ Germany.                                75.444840          0
# Tel Aviv Univ Israel.                                75.088968          0
# Univ Southampton England.                            74.733096          0
#
# [71 rows x 5 columns]
